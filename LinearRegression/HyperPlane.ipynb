# %%
from sklearn.datasets import make_regression # Inbuilt Dataset
import pandas as pd
import numpy as np

# %%
import plotly.express as px  #3D visualization
import plotly.graph_objects as go

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
X, y = make_regression(n_samples = 100, n_features = 2, n_informative = 2, n_targets = 1, noise = 50)

# %%
df = pd.DataFrame({'feature1' : X[:,0], 'feature2' : X[:, 1], 'target' : y})

# %%
df.head()
# Out:
#    feature1  feature2      target
# 0  0.715746  0.953960  103.511570
# 1  1.338766  2.195703  179.014805
# 2  0.299211 -0.889620   24.279217
# 3 -0.992846 -0.100409  -72.386625
# 4  0.394329 -1.610594  -28.320491

# %%
fig = px.scatter_3d(df, x = 'feature1', y = 'feature2', z = 'target')
fig.show()
# Out:
# <div>                            <div id="84320aee-3818-4719-a926-a74538d4a9e8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("84320aee-3818-4719-a926-a74538d4a9e8")) {                    Plotly.newPlot(                        "84320aee-3818-4719-a926-a74538d4a9e8",                        [{"hovertemplate":"feature1=%{x}<br>feature2=%{y}<br>target=%{z}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":[0.7157457455974662,1.3387663279341224,0.2992108769536427,-0.9928461053888653,0.39432867721349946,0.1608378204382809,-0.551847238212285,-1.35716402884806,1.1866401704771865,1.5165354062120302,-0.5496788842633417,0.44391892993277116,1.1229983704471298,-0.925
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 3)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
print("MAE : ", mean_absolute_error(y_test, y_pred))
# Out:
# MAE :  38.426965409341605

# %%
print("MSE : ", mean_squared_error(y_test, y_pred))
# Out:
# MSE :  1914.7338986324019

# %%
print("R2 score : ",r2_score(y_test, y_pred))
# Out:
# R2 score :  0.812289489818802

# %%
x = np.linspace(-5, 5, 10)
y = np.linspace(-5, 5, 10)
xGrid, yGrid = np.meshgrid(y, x)
final = np.vstack((xGrid.ravel().reshape(1, -1), yGrid.ravel().reshape(1, -1)))
z_final = lr.predict(final.T).reshape(10, 10)

# %%
z = z_final

# %%
fig = px.scatter_3d(df, x = 'feature1', y = 'feature2', z = 'target')
fig.add_trace(go.Surface(x = x, y = y, z = z))
fig.show()
# Out:
# <div>                            <div id="26fc14da-be7e-41e6-88b4-a541b008fb95" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("26fc14da-be7e-41e6-88b4-a541b008fb95")) {                    Plotly.newPlot(                        "26fc14da-be7e-41e6-88b4-a541b008fb95",                        [{"hovertemplate":"feature1=%{x}<br>feature2=%{y}<br>target=%{z}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":[0.7157457455974662,1.3387663279341224,0.2992108769536427,-0.9928461053888653,0.39432867721349946,0.1608378204382809,-0.551847238212285,-1.35716402884806,1.1866401704771865,1.5165354062120302,-0.5496788842633417,0.44391892993277116,1.1229983704471298,-0.925
# ...

# %%
from sklearn.datasets import load_diabetes # Already present dataset

# %%
X1, y1 = load_diabetes(return_X_y = True)

# %%
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size = 0.2, random_state = 3)

# %%
regression = LinearRegression()

# %%
regression.fit(X1_train, y1_train) # BEST FIT Line
# Out:
# LinearRegression()

# %%
y1_predict = regression.predict(X1_test)

# %%
data = load_diabetes()

X1 = data.data 
y1 = data.target 

df1 = pd.DataFrame(X1, columns=data.feature_names)

# %%
df1.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019907 -0.017646
# 1 -0.039493 -0.068332 -0.092204
# 2 -0.002592  0.002861 -0.025930
# 3  0.034309  0.022688 -0.009362
# 4 -0.002592 -0.031988 -0.046641

# %%
lr.fit(X1_train, y1_train)
# Out:
# LinearRegression()

# %%
y1_pred = lr.predict(X1_test)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
df1 = pd.DataFrame(data.data, columns=data.feature_names)

# %%
x = df1['age']
y = df1['bmi']
z = df1['bp']
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(x, y, z, c=z, cmap='viridis', marker='o')

ax.set_xlabel('Age')
ax.set_ylabel('BMI')
ax.set_zlabel('BP')
colorbar = fig.colorbar(scatter, ax=ax, pad=0.1, label='BP values')

plt.show()

# %%
x = 7 * np.random.rand(100, 1) - 2.8
y = T
